# %% [markdown]
# <a href="https://colab.research.google.com/github/haseeb-dev-sys/python-30/blob/main/fundamentals/day01_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Day 1 — Python Basics

# 1. Variables and data types
name = "Haseeb"
age = 17
is_learning = True

# 2. Printing
print("Hello, Python world!")
print("Name:", name)
print(f"{name} is learning Python.")

# 3. Basic arithmetic
a = 10
b = 3
print("Addition:", a + b)
print("Division:", a / b)
print("Integer division:", a // b)
print("Power:", a ** b)

# 4. Lists
numbers = [1, 2, 3, 4]
numbers.append(5)
print("Numbers:", numbers)

# 5. Dictionary
person = {
    "name": "Haseeb",
    "age": 17,
}
print("Person:", person)
print("Name inside dict:", person["name"])

# 6. User input (commented)
# user_name = input("Enter your name:")
# print(f"Welcome, {user_name}!")

print("Day 1 complete!")
